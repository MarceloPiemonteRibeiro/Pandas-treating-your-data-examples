# %% [markdown]
# # Relatório de Análise IV

# %% [markdown]
# Seleções e Frequências

# %%
import pandas as pd

# %% [markdown]
# Lembre se da ultima aula que criamos um dataFrame so com os imoveis residenciais, ele sera usado novamente aqui

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep=';')

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# ...

# %%
# Selecione somente os imóveis classificados com tipo 'Apartamento'.
selecao=dados['Tipo']=='Apartamento'
selecao.head(10)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# 9     True
# Name: Tipo, dtype: bool

# %%
n1=dados[selecao]
n1
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# 5      Apartamento              Cachambi        2      0       0    50
# 8      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 22573  Apartamento        Vila Valqueire        2      0       0    52
# 22575  Apartamento                 Méier        2      0       0    70
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# ...

# %%
n1=dados[selecao].shape[0]
n1
#19532 apartamentos
# Out:
# 19532

# %%
# Selecione os imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'.
selecao = (dados['Tipo']=='Casa')|(dados['Tipo']== 'Casa de Condomínio') |(dados['Tipo']=='Casa de Vila')
n2=dados[selecao].shape[0]
n2
#2212 imoveis nessas características
# Out:
# 2212

# %%
# Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.
# 60<=Area<=100
selecao=(dados['Area']>=60)&(dados['Area']<=100)
n3=dados[selecao].shape[0]
n3
#8719 impveis nessas caracteristicas
# Out:
# 8719

# %%
# Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.
selecao=(dados['Quartos']>=4) & (dados['Valor']<2000)
n4=dados[selecao].shape[0]
n4
# 41 imoveis
# Out:
# 41

# %%
#outra forma (forum)
seleca_area = dados.query('Area>=60 & Area<=100')
print(seleca_area)

selecao = dados.query('Quartos>= 4 & Valor < 2000')
print(selecao)
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 4             Apartamento              Vista Alegre        3      1       0
# 7      Casa de Condomínio                     Ramos        2      2       0
# 9             Apartamento                    Grajaú        2      1       0
# 10            Apartamento       Lins de Vasconcelos        3      1       1
# ...                   ...                       ...      ...    ...     ...
# 22568         Apartamento  Recreio dos Bandeirantes        3      2       1
# 22570         Apartamento                    Leblon        3      0       1
# 22575         Apartamento                     Méier        2      0       0
# 22577         Apartamento               Jacarepaguá        3      1       2
# 22579         Apartamento                    Leblon        2      0       0
#
#        Area   Valor  Condominio   IPTU
# ...

# %%
#Forum, usando or e and
selecao = dados.query("Tipo == 'Casa' or Tipo == 'Casa de Condomínio' or Tipo == 'Casa de Vila'")
selecao
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 6      Casa de Condomínio          Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                    Ramos        2      2       0
# 14     Casa de Condomínio                  Taquara        3      1       1
# 18     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                   ...                      ...      ...    ...     ...
# 22545  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 22547                Casa            Bento Ribeiro        2      1       0
# 22555  Casa de Condomínio          Barra da Tijuca        3      5       3
# 22558                Casa                   Centro        5      0       1
# 22574  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU
# ...

# %% [markdown]
# Forum : Porque nao usar and e or https://stackoverflow.com/questions/36921951/truth-value-of-a-series-is-ambiguous-use-a-empty-a-bool-a-item-a-any-o

# %% [markdown]
# Voce pode selecionar a celula abaixo e clicar em edit e "find and replace" para alterar o "Selcione os" de todas as linhas

# %%
print("N° de imóveis classificados com tipo 'Apartamento'->{}".format(n1))
print("N° de imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'. ->{}".format(n2))
print("N° de imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.->{}".format(n3))
print("N° de imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.->{}".format(n4))
# Out:
# N° de imóveis classificados com tipo 'Apartamento'->19532
# N° de imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'. ->2212
# N° de imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.->8719
# N° de imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.->41

# %% [markdown]
# Forum: Usar a funcao contains se vc quiser filtrar tipos com uma palavra especifica

# %%
# Você pode utilizar o contains para verificar se uma string contém outra
selecao = dados['Tipo'].str.contains('Casa')
selecao
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 22575    False
# 22576    False
# 22577    False
# 22578    False
# 22579    False
# Name: Tipo, Length: 22580, dtype: bool

# %%
# ou 
selecao = dados['Tipo'].str.contains('Casa*', regex=True)
selecao
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 22575    False
# 22576    False
# 22577    False
# 22578    False
# 22579    False
# Name: Tipo, Length: 22580, dtype: bool

# %%
# ou
seleção = dados[['Casa' in i for i in dados['Tipo']]]
selecao
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 22575    False
# 22576    False
# 22577    False
# 22578    False
# 22579    False
# Name: Tipo, Length: 22580, dtype: bool

# %% [markdown]
# Forum: Se contarmos as suites separadamente, como se fossem quartos a mais , podemos fazer da forma abaixo.. pode nao fazer muito sentido para esse exercicio mas se vc quiser que uma condição seja a soma ou qq outra operação, vc pode fazer dessa forma.

# %%
selecao3 = (dados['Quartos'] + dados['Suites'] >= 4) & (dados['Valor'] < 2000)
selecao3
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22575    False
# 22576    False
# 22577     True
# 22578    False
# 22579    False
# Length: 22580, dtype: bool

# %%
n4 = dados[selecao3].shape[0]
n4
# Out:
# 762

# %% [markdown]
# Exercicio

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
# selecione so os aprovados
selecao = alunos['Aprovado'] == True
aprovados = alunos[selecao]
aprovados
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
selecao = (alunos['Aprovado'] == True) & (alunos['Notas'] >= 8.0)
aprovados = alunos[selecao] 
aprovados
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True

# %%
# so alunas aprovadas
selecao = (alunos.Aprovado == True) & (alunos.Sexo == 'F')
aprovadas = alunos[selecao]
aprovadas
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
# alternativamente - mas esse método é preferivel se entre [] eu tenho duas palavras, e.g. ['Idade Média']
selecao = (alunos['Aprovado'] == True) & (alunos['Sexo'] == 'F')
aprovadas = alunos[selecao]
aprovadas
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
# modificar o indice
selecao = (alunos.Aprovado == True) & (alunos.Sexo == 'F')
aprovadas = alunos[selecao].reset_index(drop=True)
aprovadas
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0  Bruna     42    F    8.2      True
# 1   Dara     21    F    7.0      True

# %%
# definir o nome como indice
selecao = (alunos.Aprovado == True) & (alunos.Sexo == 'F')
aprovadas = alunos[selecao].set_index('Nome', drop=True)
aprovadas
# Out:
#        Idade Sexo  Notas  Aprovado
# Nome
# Bruna     42    F    8.2      True
# Dara      21    F    7.0      True

# %%
# nao visualizar indice
selecao = (alunos.Aprovado == True) & (alunos.Sexo == 'F')
aprovadas = alunos[selecao]
print(aprovadas.to_string(index=False))
# Out:
#   Nome  Idade Sexo  Notas  Aprovado
#  Bruna     42    F    8.2      True
#   Dara     21    F    7.0      True

# %%
# alunos com idade entre 10 e 20 anos ou com idade maior ou igual a 40 anos.
selecao = (alunos.Idade > 10) & (alunos.Idade < 20) | (alunos.Idade >= 40)
alunos[selecao]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 2   Denis     56    M    5.0     False
# 4   Bruna     42    F    8.2      True
# 6  Carlos     19    M    6.0     False
